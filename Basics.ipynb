# %%
a = 5;
b = 10;
c = a + b;
print(c);
# Out:
# 15

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [5,10,15,20,25,30];
y = [1,2,3,4,5,6];

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()
